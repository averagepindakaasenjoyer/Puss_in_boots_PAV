# %%
import nltk
from nltk.parse.corenlp import CoreNLPParser
from nltk.tokenize import sent_tokenize
import contractions
import re

# Download the punkt tokenizer if not already downloaded
nltk.download('punkt')

# Function to preprocess a sentence
def preprocess_sentence(sentence):
    # Convert to lowercase
    sentence = sentence.lower()
    # Expand contractions
    sentence = contractions.fix(sentence)
    # Remove non-alphanumeric characters and extra whitespace
    sentence = re.sub(r'[^a-zA-Z0-9\s]', '', sentence)
    # Remove punctuation marks
    sentence = re.sub(r'[.,?!]', '', sentence)
    # Remove extra spaces
    sentence = re.sub(r'\s+', ' ', sentence)
    return sentence

# Open the file and preprocess the corpus
with open('script.txt') as script:
    text = script.read()

# Remove extra newline characters
text = text.replace('\n', ' ')

# Tokenize into sentences
sentences = sent_tokenize(text)

# Preprocess each sentence and store in a list
preprocessed_sentences = [preprocess_sentence(sentence) for sentence in sentences]

# Initialize CoreNLPParser
parser = CoreNLPParser(url="http://localhost:9100")

# Print all parse trees generated
for line in preprocessed_sentences:
    tree = next(parser.raw_parse(line))
    print(tree)
# Out:
# [nltk_data] Downloading package punkt to /home/rosa/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# (ROOT
#   (S
#     (PP (IN through) (NP (DT the) (NNS years)))
#     (NP (PRP i))
#     (VP
#       (VBP have)
#       (VP
#         (VBN been)
#         (VP (VBN known) (PP (IN by) (NP (JJ many) (NNS names))))))))
# (ROOT (NP (JJ diablo) (NN gato)))
# (ROOT (NP (DT the) (JJ furry) (NN lover)))
# (ROOT (NP (NNS chupacabra)))
# (ROOT (NP (NN friskie) (NNS twotimes)))
# (ROOT
#   (S (CC and) (NP (DT the) (NN ginger)) (VP (VBD hit) (NP (NN man)))))
# (ROOT (S (CC but) (NP (TO to)) (ADVP (RBS most))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP am) (NP (NP (NNS puss)) (PP (IN in) (NP (NNS boots)))))))
# (ROOT (S (VP (VB outlaw))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (ADVP (RB never))
#       (VP (VB forget) (S (NP (PRP you)) (NP (NN margherita)))))))
# (ROOT (S (NP (PRP i)) (VP (VBP mean) (NP (NN rosa)))))
# (ROOT (INTJ (UH sorry)))
# (ROOT
#   (S
#     (PRN (S (NP (PRP i)) (VP (VBP think) (ADVP (RB maybe)))))
#     (NP (PRP i))
#     (VP (MD should) (VP (VB go)))))
# (ROOT
#   (S
#     (PRN (S (NP (PRP you)) (VP (MD can) (RB not) (VP (VB run)))))
#     (ADVP (RB forever))
#     (VP (VB puss) (PP (IN in) (NP (NNS boots))))))
# (ROOT
#   (SBARQ (WHNP (WP what)) (SQ (MD can) (NP (PRP i)) (VP (VB say)))))
# (ROOT
#   (S (NP (PRP i)) (VP (VBD was) (NP (DT a) (JJ bad) (NN kitty)))))
# (ROOT
#   (UCP
#     (FRAG
#       (NP (RB just) (DT a) (JJ fugitive))
#       (PP (IN from) (NP (DT the) (NN law))))
#     (S (ADVP (RB forever)) (VP (VBG running)))))
# (ROOT
#   (S
#     (VP
#       (VBG searching)
#       (PP (IN for) (NP (DT a) (NN way)))
#       (S (VP (TO to) (VP (VB clear) (NP (PRP$ my) (NN name))))))))
# (ROOT
#   (S
#     (CC and)
#     (NP (PRP i))
#     (VP
#       (MD would)
#       (VP
#         (VB get)
#         (NP (DT that) (NN chance))
#         (PP (IN on) (NP (DT this) (CD one) (JJ fateful) (NN night)))))))
# (ROOT (FRAG (ADVP (RB here)) (NP (NN kitty)) (NP (NN kitty))))
# (ROOT (NP (NN raoul)))
# (ROOT
#   (S
#     (VP
#       (VB look)
#       (SBAR
#         (WHNP (WP what))
#         (S (NP (DT the) (NN cat)) (VP (VBD dragged) (PRT (RP in))))))))
# (ROOT
#   (S
#     (INTJ (UH oh))
#     (VP
#       (VB wait)
#       (S (NP (DT that)) (VP (VBZ is) (NP (DT the) (NN cat)))))))
# (ROOT (FRAG (NP (CD one) (NN leche)) (INTJ (UH please))))
# (ROOT
#   (SBARQ
#     (WHNP (WP what))
#     (SQ
#       (VBP are)
#       (NP (PRP you))
#       (VP (VBG doing) (ADVP (RB here)) (NP (NN seor))))))
# (ROOT
#   (SQ
#     (VBD did)
#     (NP (PRP you))
#     (VP
#       (VB lose)
#       (NP (NP (PRP$ your) (NN ball)) (PP (IN of) (NP (NN yarn)))))))
# (ROOT (ADJP (RB so) (JJ funny)))
# (ROOT
#   (S (NP (NP (CD one) (NN leche)) (VP (VBG coming) (PRT (RP up))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP am)
#       (RB not)
#       (VP (VBG looking) (PP (IN for) (NP (NN trouble)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VP (VBP am))
#       (CC but)
#       (VP
#         (NP (DT a) (JJ humble) (NN gato))
#         (PP
#           (IN in)
#           (NP
#             (NP (NN search))
#             (PP (IN of) (NP (PRP$ his) (JJ next) (NN meal)))))))))
# (ROOT
#   (S
#     (ADVP (RB perhaps))
#     (NP (PRP you) (NNS gentlemen))
#     (VP
#       (MD can)
#       (VP
#         (VB help)
#         (S
#           (NP (PRP me))
#           (VP (VB find) (NP (DT a) (JJ simple) (NN score))))))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (JJ only) (NN thing))
#       (SBAR
#         (S
#           (NP (PRP you))
#           (VP (MD will) (VP (VB find) (NP-TMP (NN tonight)))))))
#     (VP
#       (VBZ is)
#       (NP (NP (NN trouble) (NN puss)) (PP (IN in) (NP (NNS boots)))))))
# (ROOT
#   (S
#     (INTJ (UH well))
#     (SBAR
#       (ADVP (RB perhaps))
#       (IN if)
#       (S
#         (NP (NP (CD one)) (PP (IN of) (NP (PRP us))))
#         (VP
#           (VBD were)
#           (S
#             (VP
#               (TO to)
#               (VP
#                 (VB tell)
#                 (NP
#                   (NP (DT the) (NN law))
#                   (SBAR
#                     (WHNP (WDT that))
#                     (S
#                       (NP (PRP you))
#                       (VP (VBP are) (PP (IN in) (NP (NN town)))))))))))))
#     (NP (PRP we))
#     (VP (MD could) (VP (VB split) (NP (DT the) (NN reward))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (VBD made) (S (NP (DT the) (NN cat)) (ADJP (JJ angry))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP
#         (VB want)
#         (S
#           (VP
#             (TO to)
#             (VP
#               (VB make)
#               (S (NP (DT the) (NN cat)) (ADJP (JJ angry))))))))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (NN church))
#       (PP (IN of) (NP (NNP st) (NNP michael))))
#     (VP
#       (VBZ has)
#       (ADVP (RB just))
#       (VP
#         (VBN put)
#         (PRT (RP up))
#         (NP
#           (NP (DT a) (JJ golden) (NN statue))
#           (PP
#             (IN of)
#             (NP
#               (NP (DT the) (NN virgin))
#               (PP (IN of) (NP (NN guadalupe))))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP (VB steal) (PP (IN from) (NP (NNS churches)))))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (NP (DT the) (NNS boys) (NN orphanage))
#         (VP
#           (VBZ has)
#           (VP
#             (VBN been)
#             (VP (VBN donated) (NP (NN silver) (NNS candlesticks)))))))
#     (NP (PRP they))
#     (VP
#       (MD would)
#       (VP
#         (VB look)
#         (ADJP (RB very) (JJ lovely))
#         (PP (IN in) (NP (PRP$ your) (NN home)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP (VB steal) (PP (IN from) (NP (NNS orphans)))))))
# (ROOT
#   (FRAG
#     (WHNP (WP what))
#     (PP (IN about) (NP (NN jack) (CC and) (NN jill)))))
# (ROOT (NP (NN shh)))
# (ROOT (FRAG (PRN (SQ (VBP are) (NP (PRP you)) (ADJP (JJ crazy))))))
# (ROOT (NP (NP (DT the)) (SBAR (WHNP (WP what)))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (JJ murderous) (NNS outlaws) (NN jack))
#       (CC and)
#       (NP (NN jill)))
#     (VP
#       (VBP have)
#       (VP
#         (VBN gotten)
#         (NP (PRP$ their) (NNS hands))
#         (PP (IN on) (NP (JJ magic) (NNS beans)))))))
# (ROOT
#   (S
#     (VP
#       (VB do)
#       (RB not)
#       (VP
#         (VB joke)
#         (PP (IN with) (NP (PRP me)))
#         (PP (IN about) (NP (NN magic) (NNS beans)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBD searched)
#       (NP (PDT half) (PRP$ my) (NN life))
#       (PP (IN for) (NP (PRP them))))))
# (ROOT (S (NP (PRP they)) (VP (VBP do) (RB not) (VP (VB exist)))))
# (ROOT (NP (DT no) (NN cat)))
# (ROOT
#   (S (NP (PRP we)) (VP (VBP have) (VP (VBN seen) (NP (PRP them))))))
# (ROOT
#   (S
#     (NP (DT these))
#     (VP
#       (VBP are)
#       (NP (NP (DT the) (NNS beans)) (PP (IN of) (NP (NN legend)))))))
# (ROOT
#   (S
#     (VP
#       (VBZ grows)
#       (NP (DT a) (NN vine))
#       (PP
#         (IN to)
#         (NP
#           (NP (DT the) (NN land))
#           (PP
#             (IN of)
#             (NP
#               (NP (NNS giants))
#               (CC and)
#               (NP (DT the) (JJ golden) (NN goose)))))))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (JJ golden) (NN goose))
#       (NP (NP (DT a) (NN heist)) (PP (IN like) (NP (DT this)))))
#     (VP
#       (MD could)
#       (VP
#         (VB set)
#         (NP (PRP you))
#         (PRT (RP up))
#         (PP (IN for) (NP (NN life)))))))
# (ROOT (NP (NP (DT all) (CD nine)) (PP (IN of) (NP (PRP them)))))
# (ROOT
#   (S
#     (VP
#       (VB show)
#       (NP (PRP him))
#       (NP (DT the) (JJ golden) (NNS eggs)))))
# (ROOT (INTJ (UH no)))
# (ROOT
#   (S
#     (INTJ (UH please))
#     (NP (PRP you))
#     (VP (VBP have) (VP (VBN shown) (S (ADJP (JJ enough)))))))
# (ROOT
#   (S
#     (NP
#       (NP (RB only) (DT a) (NN cat))
#       (PP (IN with) (NP (DT a) (NN death) (NN wish))))
#     (VP
#       (MD would)
#       (VP
#         (VB steal)
#         (NP (DT the) (NNS beans))
#         (PP (IN from) (NP (NN jack) (CC and) (NN jill)))))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (JJ only) (NN wish))
#       (SBAR (S (NP (PRP i)) (VP (VBP have)))))
#     (VP
#       (VBZ is)
#       (S
#         (VP (TO to) (VP (VB repay) (NP (DT an) (JJ old) (NN debt))))))))
# (ROOT
#   (S
#     (CC and)
#     (NP (DT this))
#     (VP (VBZ is) (NP (PRP$ my) (NN chance)))))
# (ROOT
#   (SBARQ
#     (ADVP (RB now))
#     (WHADVP (WRB where))
#     (SQ
#       (VBP do)
#       (NP (PRP i))
#       (VP (VB find) (NP (DT this) (NN jack) (CC and) (NN jill))))))
# (ROOT
#   (S
#     (PRN (S (NP (PRP i)) (VP (VBP am) (ADJP (JJ sorry)))))
#     (NP (PRP we))
#     (VP (VBP have) (NP (DT no) (NNS rooms)))))
# (ROOT
#   (S
#     (INTJ (UH well))
#     (NP (PRP i))
#     (VP
#       (VBP think)
#       (SBAR
#         (S
#           (NP (PRP one))
#           (ADVP (RB just))
#           (VP (VBD opened) (PRT (RP up))))))))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP
#       (MD would)
#       (VP
#         (VB like)
#         (NP
#           (DT a)
#           (JJ complimentary)
#           (JJ continental)
#           (NN breakfast))))))
# (ROOT
#   (S
#     (CC and)
#     (VP
#       (VB do)
#       (RB not)
#       (ADVP (RB even))
#       (VP
#         (VB think)
#         (PP (IN about) (NP (NN skimpin)))
#         (PP (IN on) (NP (PRP them) (NN baby) (NNS muffins)))))))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP (VB have) (NP (DT any) (NN baby) (NNS muffins))))))
# (ROOT (S (NP (PRP you)) (VP (VBP know) (NP (NN jill)))))
# (ROOT (S (NP (PRP i)) (VP (VBP been) (VP (VBG thinking)))))
# (ROOT (S (VP (VB get) (NP (PRP it)) (PRT (RP out)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (ADVP (RB once))
#     (PRN
#       (S
#         (NP (PRP we))
#         (VP
#           (VP
#             (VBP are)
#             (VP
#               (VBN done)
#               (PP
#                 (IN with)
#                 (NP
#                   (DT this)
#                   (NML (NN magic) (NN bean))
#                   (NN business)))))
#           (CC and)
#           (VP (VBD got) (NP (PRP ourselves)) (S (NP (DT all)))))))
#     (NP (PRP them))
#     (NP (JJ beautiful) (JJ golden) (NNS eggs))
#     (VP (VBP go) (PP (IN on)))))
# (ROOT
#   (SBAR
#     (IN that)
#     (S
#       (NP (PRP we))
#       (VP
#         (VBD cut)
#         (PRT (RP down))
#         (PP
#           (IN on)
#           (NP
#             (NP (DT some))
#             (PP
#               (IN of)
#               (NP (DT the) (NN hijacking) (CC and) (NN murdering)))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP mean)
#       (SBAR
#         (S
#           (NP (PRP it))
#           (VP
#             (VBZ is)
#             (UCP (ADJP (JJ fun)) (CC and) (ADVP (DT all) (RB but)))))))))
# (ROOT (S (NP (PRP i)) (VP (VBP want) (NP (DT a) (NN baby)))))
# (ROOT (FRAG (NP (DT a) (NN baby)) (NP (WDT what)) (NP (NN jack))))
# (ROOT (FRAG (NP (DT a) (NN baby)) (NP (PRP us)) (NP (NN jill))))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP
#       (MD will)
#       (VP
#         (VB raise)
#         (S
#           (NP (PRP it))
#           (ADJP
#             (JJ wild)
#             (PP
#               (IN like)
#               (NP (DT a) (NN squirrel) (CC or) (NN something)))))))))
# (ROOT (NP (JJ holy) (NNS frijoles)))
# (ROOT (S (NP (PRP they)) (VP (VBP do) (VP (VB exist)))))
# (ROOT
#   (S
#     (ADVP (RB ever))
#     (SBAR
#       (IN since)
#       (S
#         (NP (PRP you))
#         (VP
#           (VP (VBD fell) (PRT (RP down)) (NP (DT that) (NN hill)))
#           (CC and)
#           (VP (VBD broke) (NP (PRP$ your) (NN crown))))))
#     (NP (PRP you))
#     (VP
#       (VBP have)
#       (VP (VBN been) (VP (VBG talking) (ADJP (JJ crazy)))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (MD could)
#       (RB not)
#       (VP
#         (VB hurt)
#         (S
#           (VP
#             (TO to)
#             (VP
#               (VB have)
#               (NP (DT an) (JJ extra) (NN shooter))
#               (PP (IN during) (NP (NNS ambushes))))))))))
# (ROOT
#   (S
#     (ADVP (RB maybe))
#     (NP (PRP i))
#     (VP
#       (VBD cut)
#       (NP (ADJP (RB too) (JJ deep)) (NN cut))
#       (PP (NP (WDT that) (NN brain)) (IN out))
#       (PP (IN of) (NP (PRP$ your) (NN head))))))
# (ROOT (INTJ (UH hey)))
# (ROOT (SBARQ (WHNP (WP what)) (SQ (VP (VBZ gives)))))
# (ROOT
#   (S
#     (SBAR
#       (IN if)
#       (S
#         (NP (PRP it))
#         (VP
#           (VBZ is)
#           (S (VP (TO to) (VP (VB be) (NP (DT a) (NN girl))))))))
#     (NP (PRP she))
#     (VP
#       (MD will)
#       (VP (VB have) (NP (PRP$ your) (ADJP (JJ strong) (DT no)))))))
# (ROOT (INTJ (UH no)))
# (ROOT (INTJ (UH no)))
# (ROOT (FRAG (NP (PRP you)) (NP (PRP you)) (NP (PRP you))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP stop)
#       (SBAR (WHADVP (WRB where)) (S (NP (PRP you)) (VP (VBP are)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP do) (RB not) (VP (VB know) (NP (NN jack))))))
# (ROOT
#   (SBARQ
#     (WHADVP (WRB how))
#     (SQ
#       (VBP do)
#       (NP (PRP i))
#       (VP
#         (VB ride)
#         (CC and)
#         (VB shoot)
#         (SBAR
#           (IN with)
#           (S
#             (NP (DT a) (NN baby))
#             (VP (VBD slung) (PP (IN on) (NP (PRP$ my) (NN back))))))))))
# (ROOT
#   (S
#     (NP (PRP they))
#     (VP
#       (VBD got)
#       (NP (PRP them))
#       (NP (NNS backpacks))
#       (ADVP (RB now)))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (NN way))
#       (SBAR
#         (S
#           (NP (PRP i))
#           (VP
#             (VBP see)
#             (S
#               (NP (PRP it))
#               (VP (VB jill) (NP (DT those) (NNS beans))))))))
#     (VP (VBP are) (ADJP (PRP mine)))))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP
#       (VBP fall)
#       (PRT (RP off))
#       (NP
#         (NP (DT this) (JJ flat) (NN earth))
#         (NP-TMP (CD one) (NN time))))))
# (ROOT
#   (FRAG
#     (NP (WP what))
#     (NP
#       (NP (JJR better) (NN proof))
#       (PP (IN of) (NP (PRP$ our) (NN love))))
#     (NP (PRP me))))
# (ROOT (S (NP (PRP you)) (VP (VBP snap) (NP (PRP me)))))
# (ROOT (S (NP (PRP you)) (VP (VBP snap) (NP (PRP me)))))
# (ROOT
#   (SQ
#     (NP (PRP you))
#     (VP (VBG looking) (PP (IN for) (NP (NN something))))))
# (ROOT (INTJ (UH no)))
# (ROOT (NP (DT no) (NN hablo) (NNS ingls)))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (VP
#         (VBG going)
#         (S (VP (TO to) (VP (VB pay) (PP (IN for) (NP (DT this))))))))))
# (ROOT (INTJ (UH no)))
# (ROOT (NP (NNS chupacabra)))
# (ROOT (NP (NNS chupacabra)))
# (ROOT (NP (NNS chupacabra)))
# (ROOT (NP (NNS chupacabra)))
# (ROOT
#   (S (NP (PRP you)) (VP (VBP are) (NP (DT a) (JJ crazy) (NN woman)))))
# (ROOT
#   (S
#     (NP (DT those) (JJ magic) (NNS beans))
#     (VP (VBD were) (NP (PRP$ my) (NN score)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (ADVP (RB just))
#     (VP
#       (VBD cost)
#       (NP (PRP me))
#       (NP
#         (NP (DT a) (NN chance))
#         (PP
#           (IN at)
#           (S
#             (VP
#               (VBG getting)
#               (NP
#                 (NP (DT the) (JJ golden) (NNS eggs))
#                 (NP (NNP mi) (NNP amigo))))))))))
# (ROOT (S (VP (VB put) (PRT (RP up)) (NP (PRP$ your) (NNS dukes)))))
# (ROOT (ADVP (RB very) (RB well)))
# (ROOT
#   (S
#     (SBAR
#       (IN if)
#       (S
#         (NP (PRP it))
#         (VP
#           (VBZ is)
#           (S
#             (VP
#               (TO to)
#               (VP (VB be) (NP (DT a) (NN dance) (NN fight))))))))
#     (ADVP (RB then))
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (VP
#         (VB tuesdaynightdancefight)
#         (NP (PRP you))
#         (PP (IN to) (NP (DT the) (NN death)))))))
# (ROOT
#   (SBAR
#     (WHADVP (WRB how))
#     (S
#       (VP
#         (VBP dare)
#         (S
#           (NP (PRP you))
#           (VP
#             (VB do)
#             (NP (DT the) (NN litter) (NN box))
#             (PP (IN at) (NP (PRP me)))))))))
# (ROOT (INTJ (UH hello)))
# (ROOT (SQ (MD can) (NP (PRP you)) (VP (VB feel) (NP (PRP me)))))
# (ROOT
#   (S
#     (VP
#       (VB fear)
#       (NP (PRP me))
#       (SBAR (IN if) (S (NP (PRP you)) (VP (VBP dare)))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBD hit)
#       (NP (PRP me))
#       (PP (IN in) (NP (DT the) (NN head)))
#       (PP (IN with) (NP (DT a) (NN guitar))))))
# (ROOT (S (NP (PRP you)) (VP (VBP are) (NP (DT a) (NN woman)))))
# (ROOT (NP (NN amateur)))
# (ROOT (INTJ (UH wow)))
# (ROOT (NP (NN seorita) (NN wait)))
# (ROOT
#   (S
#     (VP
#       (VB let)
#       (S
#         (NP (PRP me))
#         (VP (VB buy) (NP (PRP you)) (NP (DT some) (NN leche)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP am)
#       (ADVP (NP (DT a) (NN lover)) (RB not))
#       (NP (DT a) (NN fighter)))))
# (ROOT (INTJ (UH hello)))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (VBP are) (VP (VBG hiding) (PP (IN from) (NP (PRP me)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP like)
#       (S
#         (VP
#           (TO to)
#           (VP (VB play) (NP (DT the) (NNS games)) (ADVP (RB too))))))))
# (ROOT
#   (S
#     (PRN
#       (S (NP (PRP i)) (VP (VBP sense) (PP (IN in) (NP (PRP you))))))
#     (NP-TMP (NP (DT a) (JJ kindred) (NN spirit)) (NP (DT a)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP smell) (NP (NN something)) (S (ADJP (JJ familiar))))))
# (ROOT (FRAG (NP (NN something)) (ADJP (JJ dangerous))))
# (ROOT (NP (NN something) (NN breakfasty)))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (VBZ is)
#       (VP
#         (VBN been)
#         (NP (DT a) (NML (JJ long) (NN time)) (NN brother))))))
# (ROOT (NP (NN maldito) (NN huevo)))
# (ROOT (NP (JJ humpty) (NN alexander) (NN dumpty)))
# (ROOT
#   (SBAR
#     (WHADVP (WRB how))
#     (S
#       (VP
#         (VBP dare)
#         (S
#           (NP (PRP you))
#           (VP
#             (VB show)
#             (NP (PRP$ your) (NN face))
#             (PP (IN to) (NP (PRP me)))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP know)
#       (SBAR (S (NP (PRP you)) (VP (VBP are) (ADJP (JJ angry))))))))
# (ROOT (S (NP (PRP you)) (VP (VBP have) (NP (DT every) (NN right)))))
# (ROOT
#   (S
#     (CC but)
#     (NP (PRP it))
#     (VP
#       (VBZ is)
#       (ADJP
#         (JJ good)
#         (S
#           (VP
#             (TO to)
#             (VP (VB see) (S (NP (PRP you)) (VP (VB puss))))))))))
# (ROOT (S (VP (VBP are) (NP (DT those) (JJ new) (NNS boots)))))
# (ROOT (INTJ (UH no)))
# (ROOT
#   (S
#     (NP (PRP they))
#     (VP
#       (VBP are)
#       (NP
#         (NP (DT the) (JJ same) (NNS boots))
#         (SBAR
#           (S
#             (NP (PRP i))
#             (VP
#               (VBD wore)
#               (SBAR
#                 (WHADVP (WRB when))
#                 (S (NP (PRP you)) (VP (VBD betrayed) (NP (PRP me))))))))))))
# (ROOT (FRAG (VP (VBN betrayed) (NP (PRP you)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBD left)
#       (S
#         (NP (PRP me))
#         (VP
#           (VBN cracked)
#           (PP
#             (IN in)
#             (NP
#               (NP (NNS pieces))
#               (PP
#                 (IN on)
#                 (NP
#                   (NP (DT a) (NN bridge))
#                   (VP
#                     (VBN surrounded)
#                     (PP (IN by) (NP (NNS soldiers)))))))))))))
# (ROOT
#   (S
#     (NP (PRP they))
#     (VP
#       (VBD wrote)
#       (NP (DT a) (NN song))
#       (PP (IN about) (NP (PRP it))))))
# (ROOT
#   (SBARQ
#     (CC and)
#     (WHADVP (WRB how))
#     (SQ
#       (VBD did)
#       (NP (PRP we))
#       (VP
#         (VB get)
#         (PP
#           (IN on)
#           (NP
#             (NP (DT that) (NN bridge))
#             (PP (IN in) (NP (DT the) (JJ first) (NN place)))))))))
# (ROOT
#   (SBAR
#     (IN because)
#     (S
#       (NP (PRP we))
#       (VP
#         (VBD were)
#         (NP
#           (NP (NNS brothers) (CC and) (NNS brothers))
#           (SBAR
#             (S
#               (VP
#                 (VBP are)
#                 (VP
#                   (VBN supposed)
#                   (S
#                     (VP
#                       (TO to)
#                       (VP
#                         (VB look)
#                         (PP
#                           (IN after)
#                           (NP (DT each) (JJ other) (NN humpty)))))))))))))))
# (ROOT
#   (S
#     (VP
#       (VB remember)
#       (SBAR
#         (WHADVP (WRB why))
#         (S (NP (PRP we)) (VP (VBP are) (ADVP (RB here))))))))
# (ROOT
#   (S (NP (PRP i)) (VP (MD should) (VP (VB have) (VP (VBN known))))))
# (ROOT
#   (S
#     (S
#       (NP (PRP i))
#       (VP
#         (VBD had)
#         (NP
#           (NP (DT the) (NN magic) (NNS beans))
#           (PP (IN in) (NP (PRP$ my) (NN grasp))))))
#     (CC and)
#     (S
#       (NP (PRP you))
#       (VP
#         (VBD sent)
#         (NP
#           (DT this)
#           (ADJP (RB very) (JJ attractive))
#           (NN devil)
#           (NN woman))
#         (S (VP (TO to) (VP (VB interfere))))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (NP
#         (NP (DT a) (NN curse))
#         (PP (IN on) (NP (PRP$ my) (NN life)))))))
# (ROOT (S (VP (VB wait))))
# (ROOT (S (VP (VB hear) (NP (PRP me)) (PRT (RP out)))))
# (ROOT (INTJ (UH ok)))
# (ROOT
#   (S
#     (INTJ (UH yes))
#     (INTJ (UH yes))
#     (NP (PRP i))
#     (VP
#       (VBD sent)
#       (NP (NN kitty))
#       (S
#         (VP (TO to) (VP (VB bring) (NP (PRP you)) (ADVP (RB here))))))))
# (ROOT
#   (S
#     (CC but)
#     (NP (PRP she))
#     (VP (VBZ is) (NP (DT no) (JJ ordinary) (NN thief)))))
# (ROOT
#   (S (NP (PRP she)) (VP (VBZ is) (NP (NN kitty) (NNS softpaws)))))
# (ROOT
#   (NP
#     (NP (DT the) (JJS softest) (NN touch))
#     (PP (IN in) (NP (NNP spain)))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (NP (DT that))
#         (VP
#           (VBZ is)
#           (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (NN heel))))
#           (SBAR
#             (IN for)
#             (S (NP (DT a) (NN guy)) (VP (VBP do) (RB not)))))))
#     (NP (PRP you))
#     (VP (VBP think))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (VP
#           (VB look)
#           (PP (IN with) (NP (NN kittys) (NN skill)))
#           (NP
#             (NP (PRP$ your) (NN sword))
#             (CC and)
#             (NP (PRP$ my) (NN brain))))))
#     (NP (PRP we))
#     (VP
#       (VBP have)
#       (VP
#         (VBN got)
#         (NP (DT a) (NN fighting) (NN chance))
#         (ADVP (RB here))))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (NP (NNS puss))
#         (VP
#           (VBP come)
#           (PP (IN on) (NP (NP (PRP you)) (PP (IN of) (NP (DT all))))))))
#     (NP (NNS people))
#     (VP
#       (VBP know)
#       (SBAR
#         (IN that)
#         (S
#           (NP (NNS nobodys))
#           (ADVP (RB ever))
#           (VP
#             (VP
#               (VBD ripped)
#               (PRT (RP off))
#               (NP (DT the) (NNS giants) (NN castle)))
#             (CC and)
#             (VP
#               (VBD lived)
#               (S (VP (TO to) (VP (VB tell) (NP (DT the) (NN tale))))))))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (VBP want) (S (VP (TO to) (VP (VB survive)))))))
# (ROOT (S (NP (PRP you)) (VP (VBP need) (NP (DT a) (NN plan)))))
# (ROOT
#   (S
#     (CC and)
#     (NP (PRP i))
#     (VP
#       (VBP have)
#       (VP
#         (VBN studied)
#         (NP
#           (NP (DT this) (NN job))
#           (NP (PRP$ my) (JJ whole) (NN life)))))))
# (ROOT (S (NP (PRP you)) (VP (VBP know) (NP (DT that)))))
# (ROOT
#   (S (VP (VB let) (S (NP (PRP us)) (VP (VB be) (ADJP (JJ honest)))))))
# (ROOT
#   (S
#     (PP (IN without) (NP (PRP me)))
#     (NP (PRP you))
#     (VP
#       (VBP do)
#       (RB not)
#       (ADVP (RB even))
#       (VP
#         (VB know)
#         (SBAR
#           (WHADVP (WRB where))
#           (S
#             (VP
#               (TO to)
#               (VP (VB plant) (NP (DT the) (NNS beans) (NN puss))))))))))
# (ROOT (S (CC but) (NP (NNP jack) (CC and) (NNP jill)) (VP (VBP do))))
# (ROOT
#   (S
#     (NP (PRP they))
#     (VP (VBP are) (PP (IN on) (NP (PRP$ their) (NN way))))))
# (ROOT
#   (S
#     (S
#       (NP (PRP we))
#       (VP
#         (VBP go)
#         (PRT (RP up))
#         (NP (DT the) (NN beanstalk) (NNS outlaws))))
#     (CC and)
#     (S
#       (NP (PRP we))
#       (VP (VBP come) (PRT (RP down)) (NP (NNS legends))))))
# (ROOT
#   (SBARQ
#     (ADVP (RB so))
#     (WHNP (WP what))
#     (SQ (VBP do) (NP (PRP you)) (VP (VB say)))))
# (ROOT (NP (NNS partners)))
# (ROOT (INTJ (UH no)))
# (ROOT (S (ADVP (RB never)) (ADVP (RB again))))
# (ROOT (S (NP (PRP i)) (VP (VBP am) (ADJP (JJ sorry) (JJ ok)))))
# (ROOT
#   (SBARQ
#     (WHADVP (WRB how) (RB long))
#     (SQ
#       (VBP are)
#       (NP (PRP you))
#       (VP
#         (VBG going)
#         (S (VP (TO to) (VP (VB hold) (NP (DT a) (NN grudge)))))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP (VBZ is) (VP (VBN been) (NP (CD seven) (NNS years))))))
# (ROOT
#   (S
#     (NP (DT that))
#     (VP (VBZ is) (PP (IN like) (NP (CD 35) (NN cat) (NNS years))))))
# (ROOT (S (NP (PRP you)) (VP (VBP need) (NP (PRP me)))))
# (ROOT (S (CC and) (NP (PRP i)) (VP (VBP need) (NP (PRP you)))))
# (ROOT (NP (NN puss)))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBD got)
#       (NP
#         (NP (DT any) (NN idea))
#         (SBAR
#           (WHNP (WP what))
#           (S
#             (NP (PRP they))
#             (VP
#               (VBP do)
#               (PP
#                 (IN to)
#                 (NP
#                   (NP (NNS eggs))
#                   (PP
#                     (IN in)
#                     (NP (NP (FW san) (FW ricardo)) (NP (NN prison)))))))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (VP
#         (VB tell)
#         (NP (PRP you))
#         (NP (DT this) (PRP$ my) (NN friend))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP (VBP are) (RB not) (ADVP (RB over)) (ADJP (JJ easy)))))
# (ROOT (FRAG (NP (NN adis)) (NP (JJ humpty) (NN dumpty))))
# (ROOT
#   (S (INTJ (UH oh)) (NP (DT this)) (VP (VBZ is) (ADJP (JJ bad)))))
# (ROOT (S (NP (DT this)) (VP (VBZ is) (ADJP (JJ bad)))))
# (ROOT
#   (S
#     (VP
#       (VBP do)
#       (RB not)
#       (VP
#         (VB worry)
#         (SBAR
#           (S
#             (NP (PRP i))
#             (VP
#               (MD will)
#               (VP
#                 (VB take)
#                 (NP (NP (NN care)) (PP (IN of) (NP (PRP it))))))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP know)
#       (SBAR
#         (WHADVP (WRB how))
#         (S (VP (TO to) (VP (VB speak) (NP (NN meow)))))))))
# (ROOT
#   (NP
#     (NP (JJ sad) (NN story))
#     (PP
#       (IN with)
#       (NP
#         (NP (PRP$ your) (VBN twisted) (NNS lies))
#         (PP
#           (IN in)
#           (NP
#             (NP
#               (NP (PRP$ your) (JJ greasy))
#               (SBAR (S (NP (PRP she)) (VP (MD will)))))
#             (SBAR
#               (WHNP (WDT that))
#               (S
#                 (VP
#                   (VBZ smells)
#                   (PP (IN like) (NP (JJ old) (NN ham))))))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD should)
#       (VP
#         (VB crack)
#         (S
#           (NP (PRP you))
#           (VP
#             (VB open)
#             (PP (IN for) (NP (NN look)))
#             (SBAR
#               (WHNP (WDT what))
#               (S (NP (PRP i)) (VP (VBD found))))))))))
# (ROOT
#   (S (NP (NN someone)) (VP (VBD forgot) (NP (PRP$ his) (NN money)))))
# (ROOT
#   (S
#     (INTJ (UH oh))
#     (NP (PRP you))
#     (VP (VBP are) (ADJP (JJ dangerous)))))
# (ROOT
#   (S
#     (NP (NN humpty))
#     (VP (VBZ says) (NP (PRP you)) (PP (IN like) (NP (NN danger))))))
# (ROOT
#   (S
#     (ADVP (RB just))
#     (PRN
#       (S
#         (VP
#           (VB think)
#           (PP (IN of) (NP (PDT all) (DT the) (NN trouble))))))
#     (NP (PRP we))
#     (VP (MD can) (VP (VB get) (PP (IN into))))))
# (ROOT
#   (S
#     (NP (NP (DT the) (CD two)) (PP (IN of) (NP (PRP us))))
#     (ADVP (RB together))))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP
#       (MD can)
#       (VP
#         (VB steal)
#         (NP
#           (NP (DT a) (NN lot))
#           (PP (IN of) (NP (JJ golden) (NNS eggs))))))))
# (ROOT (S (CC and) (NP (PRP you)) (VP (VBP owe) (NP (PRP me)))))
# (ROOT (S (NP (PRP i)) (VP (VBP owe) (NP (PRP you)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBD hit)
#       (NP (PRP me))
#       (PP (IN in) (NP (DT the) (NN head)))
#       (PP (IN with) (NP (DT a) (NN guitar))))))
# (ROOT (S (NP (PRP i)) (VP (VBP regret) (NP (DT the) (NN guitar)))))
# (ROOT
#   (S (INTJ (UH ok)) (NP (PRP i)) (VP (VBP forgive) (NP (PRP you)))))
# (ROOT (S (ADVP (RB so)) (NP (PRP you)) (VP (VBP are) (PP (IN in)))))
# (ROOT
#   (SINV
#     (ADVP (RB there))
#     (VP (VBZ is) (ADJP (NML (CD one) (NN teeny)) (JJ tiny)))
#     (NP (JJ ittybitty) (NN problem))))
# (ROOT (SBARQ (CC and) (WHNP (WP what)) (SQ (VBZ is) (NP (DT that)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (VBP work) (PP (IN for) (NP (DT the) (NN egg))))))
# (ROOT (S (VP (VB come) (PP (IN on) (NP (NN puss))))))
# (ROOT
#   (SBARQ
#     (WHNP (WP what))
#     (SQ
#       (VP
#         (VP (VBD happened) (PP (IN between) (NP (PRP you))))
#         (CC and)
#         (VP
#           (VB humpty)
#           (SBAR
#             (S (NP (DT that)) (VP (VBD was) (ADJP (RB so) (JJ bad))))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VP (VBP am) (ADJP (JJ afraid) (PP (IN with) (NP (PRP me)))))
#       (CC and)
#       (VP
#         (VB humpty)
#         (SBAR
#           (S
#             (NP (DT the) (NNS scars))
#             (VP (VBP are) (ADJP (RB too) (JJ deep)))))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (NP (DT all))
#     (VP
#       (VBD started)
#       (ADVP (NP (DT a) (JJ long) (NN time)) (RB ago)))))
# (ROOT (FRAG (INTJ (UH oh)) (INTJ (UH no))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (ADVP (RB really))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP
#         (VB have)
#         (S
#           (VP
#             (TO to)
#             (VP
#               (VB tell)
#               (NP (PRP me))
#               (NP (PRP$ your) (JJ whole) (NN life) (NN story))
#               (INTJ (UH please)))))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (MD may) (VP (VB want) (S (VP (TO to) (VP (VB sit))))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (VBZ is)
#       (PP (IN at) (NP (NNS times)))
#       (ADJP (RB quite) (JJ painful)))))
# (ROOT
#   (S (INTJ (UH ok)) (ADVP (RB here)) (NP (PRP we)) (VP (VBP go))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (VBD was)
#       (NP
#         (NP (DT a) (NN year))
#         (SBAR
#           (WHPP (IN in) (WHNP (WDT which)))
#           (S
#             (NP (DT the) (NN rain))
#             (VP (VBD had) (RB not) (VP (VBN fallen)))))))))
# (ROOT
#   (S
#     (S (NP (DT the) (NN wind)) (VP (VBD was) (ADJP (JJ big))))
#     (CC and)
#     (S (NP (DT the) (NN basket)) (VP (VBD was) (ADJP (JJ small))))))
# (ROOT
#   (S
#     (PP (IN for) (NP (NNS days)))
#     (NP (PRP i))
#     (VP
#       (VBD bounced)
#       (PP
#         (IN along)
#         (NP
#           (NP (DT a) (JJ hungry) (JJ little) (NN kitten))
#           (PP (IN with) (NP (DT no) (NN milk)))))
#       (NP
#         (NP (DT no) (NN mama))
#         (CC and)
#         (NP (DT no) (NN litter) (NN box))))))
# (ROOT
#   (SBAR
#     (IN until)
#     (S
#       (NP (PRP i))
#       (VP
#         (VBD came)
#         (S
#           (VP
#             (TO to)
#             (VP
#               (VB rest)
#               (PP
#                 (IN at)
#                 (NP
#                   (NP (DT a) (NN home))
#                   (PP (IN for) (NP (VBN lost) (NNS children))))))))))))
# (ROOT (S (NP (PRP$ her) (NN name)) (VP (VBD was) (NP (NNP imelda)))))
# (ROOT
#   (S
#     (CC and)
#     (INTJ (INTJ (UH like)) (NP (DT a) (NN mother)))
#     (NP (PRP she))
#     (VP
#       (VP
#         (VBD took)
#         (NP (PRP me))
#         (PP (IN into) (NP (PRP$ her) (NN heart))))
#       (CC and)
#       (VP
#         (VBD raised)
#         (NP (PRP me))
#         (PP (IN as) (NP (PRP$ her) (JJ own)))))))
# (ROOT (NP (NN silencio)))
# (ROOT (NP (NN silencio)))
# (ROOT
#   (S
#     (NP (PRP she))
#     (VP
#       (VBD was)
#       (NP (NP (DT an) (NN angel)) (PP (IN of) (NP (NN kindness)))))))
# (ROOT (NP (NN silencio)))
# (ROOT (NP (NP (JJS most)) (PP (IN of) (NP (DT the) (NN time)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD would)
#       (VP
#         (VB like)
#         (S
#           (VP
#             (TO to)
#             (VP
#               (VB introduce)
#               (NP (DT a) (JJ new) (NN boy))
#               (S (VP (VBG joining) (NP (PRP us)))))))))))
# (ROOT (S (NP (PRP it)) (VP (VBZ is) (NP (JJ ok) (NN pequeo)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (VBP show) (PP (IN with) (NP (DT the) (NN face))))))
# (ROOT (S (VP (VB go) (ADVP (RB on)))))
# (ROOT
#   (S
#     (CC and)
#     (NP (DT that))
#     (VP
#       (VBD was)
#       (NP
#         (NP (DT the) (NN moment))
#         (SBAR
#           (S
#             (NP (PRP i))
#             (VP
#               (VBD met)
#               (NP (JJ humpty) (NN alexander) (NN dumpty)))))))))
# (ROOT (FRAG (INTJ (UH hey)) (NP (NNS whiskers))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (VP
#         (VBG sitting)
#         (PP
#           (IN in)
#           (NP (JJ little) (NML (NN boy) (NNS blues)) (NN chair)))))))
# (ROOT (S (INTJ (UH oh)) (VP (VB come) (PRT (RP on)))))
# (ROOT (SQ (VBZ is) (NP (DT this)) (ADJP (JJ necessary))))
# (ROOT
#   (S
#     (SBAR (WHADVP (WRB why)) (S (VP (VBP do) (RB not))))
#     (NP (PRP you))
#     (VP
#       (VBP pick)
#       (PP
#         (IN on)
#         (NP (NP (NN somebody)) (NP (PRP$ your) (JJ own) (NN size)))))))
# (ROOT
#   (SBARQ
#     (WHNP (WP who))
#     (SQ (VP (VBD asked) (NP (PRP you)) (NP (NN breakfast))))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (VP
#           (VB remember)
#           (SBAR
#             (WHNP (WP what))
#             (S
#               (NP (NNP imelda))
#               (VP
#                 (VBZ says)
#                 (S
#                   (NP (NN boy))
#                   (ADJP (JJ blue))
#                   (SBAR
#                     (IN if)
#                     (S
#                       (NP (PRP you))
#                       (VP
#                         (VBP are)
#                         (VP
#                           (VBG going)
#                           (S
#                             (VP
#                               (TO to)
#                               (VP
#                                 (VB blow)
#                                 (NP (PRP$ your) (NN top))))))))))))))))
#     (NP (PRP you))
#     (VP
#       (VBP blow)
#       (NP (PRP$ your) (NN horn))
#       (ADVP (RB instead) (RB right)))))
# (ROOT
#   (S (VP (VB let) (S (NP (PRP us)) (VP (VB spin) (NP (PRP him)))))))
# (ROOT
#   (S
#     (INTJ (UH please))
#     (VP (VB do) (RB not) (VP (VB spin) (NP (PRP me))))))
# (ROOT (S (VP (VBP do) (RB not) (VP (VB spin) (NP (PRP me))))))
# (ROOT (ADVP (RB not) (RB again)))
# (ROOT (INTJ (UH no)))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP am) (VP (VBG going) (PP (IN to) (NP (NN yolk)))))))
# (ROOT
#   (S
#     (ADVP (RB even))
#     (SBAR
#       (IN though)
#       (S (NP (PRP he)) (VP (VBD took) (NP (PRP$ my) (NNS beans)))))
#     (NP (DT the) (NN egg))
#     (VP
#       (VBD stood)
#       (PRT (RP up))
#       (SBAR
#         (IN for)
#         (S
#           (NP (PRP me) (CC and) (PRP i))
#           (VP
#             (VBD decided)
#             (ADVP (RB then))
#             (SBAR
#               (IN that)
#               (S
#                 (NP (PRP i))
#                 (VP
#                   (MD would)
#                   (ADVP (RB always))
#                   (VP (VB have) (NP (PRP$ his) (NN back))))))))))))
# (ROOT (INTJ (UH wow)))
# (ROOT
#   (S (NP (DT that)) (VP (VBD was) (ADJP (RB very) (JJ impressive)))))
# (ROOT (NP (NNS thanks)))
# (ROOT (FRAG (INTJ (UH hey)) (NP (NN egg) (NN boy))))
# (ROOT
#   (S
#     (ADVP (RB there))
#     (VP
#       (VBD was)
#       (NP
#         (NP (NN something))
#         (PP
#           (IN about)
#           (NP
#             (NP (DT this) (JJ strange) (JJ little) (NN egg))
#             (SBAR
#               (WHNP (WDT that))
#               (S (VP (VBD intrigued) (NP (PRP me)))))))))))
# (ROOT (S (INTJ (UH oh)) (NP (PRP it)) (VP (VBZ is) (NP (PRP you)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP have)
#       (VP
#         (VBN been)
#         (VP
#           (VBG collecting)
#           (PP (IN for) (NP (NNS months)))
#           (ADVP (RB now)))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (ADVP (RB never))
#     (VP
#       (VBP know)
#       (SBAR
#         (WHADVP (WRB when))
#         (S
#           (NP (PRP you))
#           (VP
#             (VBP are)
#             (VP
#               (VBG going)
#               (S (VP (TO to) (VP (VB get) (ADJP (JJ lucky))))))))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP know)
#       (SBAR (WHNP (WP what)) (S (NP (PRP i)) (VP (VBP mean)))))))
# (ROOT
#   (S
#     (NP (JJ magic) (NNS beans))
#     (VP
#       (VBZ is)
#       (SBAR (WHNP (WP what)) (S (NP (PRP they)) (VP (VBP are)))))))
# (ROOT (INTJ (UH hello)))
# (ROOT
#   (SQ
#     (NP (PRP you))
#     (VP
#       (VBG going)
#       (S
#         (VP
#           (TO to)
#           (VP
#             (VB tell)
#             (NP
#               (NP (PDT all) (DT the) (JJ other) (NNS kids))
#               (SBAR
#                 (WHNP (WDT that))
#                 (S
#                   (NP (PRP i))
#                   (VP
#                     (VBP believe)
#                     (PP (IN in) (NP (NN magic)))
#                     (ADVP (RB now))))))))))))
# (ROOT
#   (SQ
#     (VBZ is)
#     (NP (DT that))
#     (SBAR
#       (WHNP (WP what))
#       (S
#         (NP (PRP you))
#         (VP (VBP are) (VP (VBG going) (S (VP (TO to) (VP (VB do))))))))))
# (ROOT (INTJ (UH no)))
# (ROOT
#   (SBARQ (WHNP (WP what)) (SQ (VBZ is) (NP (PRP$ your) (NN name)))))
# (ROOT
#   (SQ
#     (S
#       (NP (PRP you))
#       (VP (VBP do) (RB not) (VP (VB say) (ADJP (JJ much)))))
#     (SQ (VBP do) (NP (PRP you)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP think)
#       (SBAR
#         (S
#           (NP (PRP i))
#           (VP
#             (MD will)
#             (VP (VB call) (S (NP (PRP you)) (ADJP (JJ sparky))))))))))
# (ROOT (NP (NNS whiskers)))
# (ROOT (NP (NNP zoltar)))
# (ROOT (FRAG (ADVP (WRB how)) (NP (QP (RB about)) (NN puss))))
# (ROOT
#   (S
#     (NP (JJ humptys) (NN mind))
#     (VP
#       (VBD was)
#       (ADJP
#         (JJ full)
#         (PP (IN of) (NP (NN imagination) (CC and) (NN invention)))))))
# (ROOT
#   (SBAR
#     (WHNP (WP what))
#     (S
#       (VP
#         (VBZ is)
#         (ADVP (IN that) (NP (CD 50) (NNS feet)))
#         (ADVP (RB down) (RB there))))))
# (ROOT (S (ADVP (RB here)) (NP (PRP we)) (VP (VBP go))))
# (ROOT (S (VP (VB give) (NP (PRP me)) (NP (DT a) (NN puss)))))
# (ROOT (S (VP (VB look) (PP (IN at) (NP (PRP me))) (NP (NN puss)))))
# (ROOT (S (NP (PRP i)) (VP (VBP am) (VP (VBG flying)))))
# (ROOT
#   (S
#     (NP (PRP he))
#     (VP
#       (VBD spoke)
#       (PP (IN of) (NP (NNS legends) (CC and) (NNS adventures)))
#       (PP (IN beyond) (NP (PRP$ my) (JJ wildest) (NNS dreams))))))
# (ROOT
#   (S
#     (SBAR
#       (WHADVP (WRB when))
#       (S
#         (NP (PRP i))
#         (VP (VBP find) (NP (DT those) (JJ magic) (NNS beans)))))
#     (NP (PRP they))
#     (VP
#       (MD will)
#       (VP
#         (VB grow)
#         (NP (DT a) (NN vine))
#         (ADVP
#           (ADVP (RB straight) (RB up))
#           (PP (IN into) (NP (DT the) (NNS clouds))))
#         (SBAR
#           (WHADVP (WRB where))
#           (S
#             (NP
#               (NP (DT a) (JJ terrible))
#               (CC and)
#               (NP (DT a) (JJ fearsome) (NN giant)))
#             (VP
#               (VBZ hoards)
#               (NP
#                 (NP (PRP$ his) (JJS greatest) (NN treasure))
#                 (NP (DT the) (JJ golden) (NN goose))))))))))
# (ROOT (NP (INTJ (UH oh)) (DT the) (JJ golden) (NN goose)))
# (ROOT (FRAG (NP (RB just) (CD one))))
# (ROOT
#   (S
#     (NP
#       (NP (RB just) (CD one))
#       (PP (IN of) (NP (PRP$ her) (JJ golden) (NNS eggs))))
#     (VP
#       (MD could)
#       (VP (VB set) (NP (PRP me)) (PP (IN for) (NP (NN life)))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP (VBZ is) (NP (PRP$ my) (NN destiny) (NN puss)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD can)
#       (RB not)
#       (ADVP (RB really))
#       (VP
#         (VB explain)
#         (NP (PRP it))
#         (SBAR
#           (CC but)
#           (S
#             (NP (PRP i))
#             (ADVP (RB just))
#             (VP
#               (VBP feel)
#               (SBAR
#                 (IN like)
#                 (S
#                   (NP (PRP i))
#                   (VP (VBP belong) (ADVP (RB up) (RB there))))))))))))
# (ROOT (FRAG (INTJ (UH oh)) (INTJ (UH boy))))
# (ROOT (S (NP (DT this)) (VP (VBZ is) (ADJP (JJ awkward)))))
# (ROOT
#   (S
#     (NP (DT this))
#     (VP
#       (VBZ is)
#       (NP
#         (NP (NN kind))
#         (PP (IN of) (NP (DT a) (NN solo) (NN dream))))
#       (ADVP (RB here)))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (NP (PRP i))
#         (VP
#           (VBP do)
#           (RB not)
#           (VP (VB need) (NP (DT any) (JJ dead) (NN weight))))))
#     (NP (PRP you))
#     (VP
#       (VBP know)
#       (S (VP (VBG holding) (NP (PRP me)) (PRT (RP down)))))))
# (ROOT
#   (SBARQ
#     (WHNP (WP what))
#     (SQ (VBP are) (NP (PRP you)) (VP (VBG doing)))))
# (ROOT
#   (S
#     (INTJ (UH oh))
#     (INTJ (UH man))
#     (NP (DT that))
#     (VP (VBZ is) (ADJP (JJ good)))))
# (ROOT
#   (S
#     (NP
#       (NP (DT the) (NN eye) (NN thing))
#       (SBAR
#         (WHNP (WDT that))
#         (S
#           (NP (PRP you))
#           (VP (VBP are) (VP (VBG doing) (NP (DT that)))))))
#     (VP (VBZ is) (ADJP (RB really) (JJ splendid)))))
# (ROOT
#   (S
#     (INTJ (UH ok))
#     (VP
#       (VB let)
#       (SBAR
#         (S
#           (NP (PRP me))
#           (ADVP (RB just))
#           (VP (VBP think) (PP (IN for) (NP (DT a) (JJ second)))))))))
# (ROOT (FRAG (ADVP (RB all) (RB right)) (ADJP (JJ ok))))
# (ROOT
#   (S (NP (DT this)) (VP (VBZ is) (ADJP (JJ crazy)) (ADVP (CC but)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP am) (VP (VBG considering) (NP (DT a) (NN partnership))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (ADVP (RB just))
#     (VP
#       (VBP need)
#       (S (VP (TO to) (VP (VB know) (NP (CD one) (NN thing))))))))
# (ROOT (SQ (MD can) (NP (PRP you)) (VP (VB commit))))
# (ROOT (NP (NN s)))
# (ROOT (S (NP (PRP i)) (VP (MD can) (VP (VB commit)))))
# (ROOT (S (INTJ (UH oh)) (NP (PRP you)) (VP (MD can) (VP (VB talk)))))
# (ROOT
#   (SQ
#     (MD could)
#     (NP (PRP you))
#     (VP (VB help) (NP (PRP me)) (PRT (RP up)))))
# (ROOT
#   (S
#     (NP-TMP
#       (NP (JJ ok) (JJ first) (NN rule))
#       (PP (IN of) (NP (NN bean) (NN club))))
#     (NP (PRP you))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP (VB talk) (PP (IN about) (NP (NN bean) (NN club)))))))
# (ROOT
#   (S
#     (NP
#       (NP (JJ second) (NN rule))
#       (PP (IN of) (NP (NN bean) (NN club))))
#     (VP
#       (VBZ is)
#       (SBAR
#         (S
#           (NP (PRP you))
#           (VP
#             (VBP do)
#             (RB not)
#             (VP (VB talk) (PP (IN about) (NP (NN bean) (NN club))))))))))
# (ROOT (S (NP (PRP you)) (ADJP (JJ ready))))
# (ROOT (ADJP (JJ ready)))
# (ROOT
#   (FRAG
#     (PP
#       (IN from)
#       (S
#         (S
#           (ADVP (NP (DT this) (NN day)) (RB forth))
#           (NP (PRP it))
#           (VP
#             (MD shall)
#             (VP
#               (VB be)
#               (VP
#                 (VBN known)
#                 (ADVP (RB never) (JJ alone))
#                 (PP
#                   (ADVP (RB always))
#                   (RB together)
#                   (ADJP (JJ humpty)))))))
#         (CC and)
#         (S (NP (NN puss) (NNS brothers)) (ADVP (RB forever)))))))
# (ROOT
#   (S
#     (CC and)
#     (ADVP (PP (IN from) (NP (DT that) (NN moment))) (IN on))
#     (NP (PRP we))
#     (VP
#       (VBD were)
#       (VP
#         (VBN united)
#         (PP (IN on) (NP (DT a) (JJ great) (NN adventure)))
#         (S
#           (VP
#             (TO to)
#             (VP (VB find) (NP (DT the) (NN magic) (NNS beans)))))))))
# (ROOT (S (VP (VB help) (NP (PRP me)) (PRT (RP up)))))
# (ROOT (FRAG (NP (NN egg)) (NP (PRP me))))
# (ROOT
#   (S
#     (NP (NN humpty))
#     (VP
#       (VBD was)
#       (NP (NP (DT the) (NNS brains)) (ADJP (JJ good) (JJ gracious))))))
# (ROOT
#   (S (NP (PRP i)) (ADVP (RB never)) (VP (VBD saw) (NP (PRP him)))))
# (ROOT (FRAG (NP (DT that)) (VP (ADVP (RB really)) (VBN hurt))))
# (ROOT
#   (S (CC and) (NP (PRP i)) (VP (VBD was) (NP (DT the) (NN skill)))))
# (ROOT (S (NP (PRP i)) (VP (VBP am) (VP (VBN cracked)))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (NP (PRP we))
#         (VP
#           (VBD got)
#           (NP (JJ red) (NNS beans))
#           (NP (JJ green) (NNS beans)))))
#     (NP (NN coffee) (NNS beans))
#     (VP
#       (VBP lima)
#       (NP
#         (NP (NNS beans))
#         (PP (CC but) (NP (DT no) (NN magic) (NNS beans)))))))
# (ROOT
#   (SQ
#     (MD would)
#     (NP (PRP you))
#     (VP (VB care) (PP (IN for) (NP (DT a) (NN jelly) (NN bean))))))
# (ROOT (S (VP (VBP thank) (NP (PRP you)))))
# (ROOT
#   (S
#     (VP
#       (VBG finding)
#       (SBAR
#         (S
#           (NP (PRP them))
#           (VP
#             (VBD meant)
#             (NP (NN everything))
#             (PP (IN to) (NP (PRP us)))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (ADVP (RB almost))
#     (VP
#       (VBD forgot)
#       (NP (DT the) (ADJP (RBS most) (JJ important)) (NN thing)))))
# (ROOT
#   (S
#     (S (NP (DT that)) (VP (VBZ is) (NP (PRP me))))
#     (CC and)
#     (S (NP (PRP you)) (VP (VBP puss)))))
# (ROOT (NP (PRP me) (CC and) (PRP you)))
# (ROOT
#   (S
#     (CC but)
#     (NP (PRP we))
#     (ADVP (RB never))
#     (VP (VBD did) (VP (VB find) (NP (PRP them))))))
# (ROOT
#   (S
#     (CC and)
#     (SBAR
#       (IN as)
#       (S
#         (NP (NNS years))
#         (VP
#           (VBD passed)
#           (NP (DT the) (NN quest))
#           (PP (IN for) (NP (JJ magic) (NNS beans))))))
#     (VP
#       (VBD seemed)
#       (ADVP (RBR more) (CC and) (RBR more))
#       (PP
#         (IN like)
#         (NP
#           (NP (DT the) (NNS dreams))
#           (PP (IN of) (NP (DT a) (NN child))))))))
# (ROOT
#   (SBAR
#     (IN as)
#     (S
#       (S (NP (NNS teenagers)) (ADJP (JJ humpty)))
#       (CC and)
#       (S
#         (NP (PRP i))
#         (VP
#           (VP (VBD looked) (PP (IN for) (NP (NN trouble))))
#           (CC and)
#           (ADVP (RB often))
#           (VP (VBD found) (NP (PRP it))))))))
# (ROOT
#   (NP
#     (NP (JJ third) (NN time))
#     (NP-TMP (DT this) (NN month))
#     (NP (NNP imelda))))
# (ROOT
#   (S (NP (JJ next) (NN time)) (VP (VBZ is) (NP (NN jail) (NN time)))))
# (ROOT
#   (S (NP (PRP they)) (VP (VBP are) (ADVP (RB just)) (NP (NNS kids)))))
# (ROOT (S (NP (PRP they)) (VP (VBP are) (NP (NNS thieves)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (ADJP (ADJP (JJR better)) (PP (IN than) (NP (DT this)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP believe)
#       (PP (IN in) (NP (PRP you)))
#       (PP (IN with) (NP (PDT all) (PRP$ my) (NN heart))))))
# (ROOT
#   (S
#     (INTJ (UH please))
#     (VP (VB do) (RB not) (VP (VB let) (NP (PRP me)) (PRT (RP down))))))
# (ROOT (S (NP (PRP i)) (VP (VBP hate) (NP (DT this) (NN place)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD can)
#       (RB not)
#       (VP
#         (VB wait)
#         (PP (IN for) (NP (PRP us)))
#         (S
#           (VP
#             (TO to)
#             (VP
#               (VB get)
#               (ADVP (IN out) (PP (IN of) (ADVP (RB here)))))))))))
# (ROOT (S (VP (VB throw) (NP (DT a) (NN rock)))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (MD will)
#       (VP
#         (VB make)
#         (S (NP (PRP you)) (VP (VB feel) (ADVP (RBR better))))))))
# (ROOT (FRAG (INTJ (UH oh)) (INTJ (UH boy))))
# (ROOT (S (NP (PRP we)) (VP (MD should) (VP (VB go)))))
# (ROOT
#   (S (PP (IN on) (NP (NN instinct))) (NP (PRP i)) (VP (VBD reacted))))
# (ROOT
#   (S
#     (NP (PRP he))
#     (VP (VBD saved) (NP (DT the) (NNS comandantes) (NN mother)))))
# (ROOT
#   (S
#     (NP (PRP he))
#     (VP (VBD saved) (NP (DT the) (NNS comandantes) (NN mother)))))
# (ROOT (S (NP (PRP you)) (VP (VBD saved) (NP (PRP$ my) (NN mother)))))
# (ROOT
#   (S
#     (NP (NN seor) (NN puss))
#     (NP (PRP he))
#     (VP (VBZ is) (NP (DT a) (NN hero)))))
# (ROOT
#   (S
#     (NP-TMP (NN today))
#     (NP (PRP we))
#     (VP
#       (VBP see)
#       (SBAR
#         (IN that)
#         (S
#           (NP (NN courage) (CC and) (NN bravery))
#           (VP (VBP come) (PP (IN in) (NP (DT all) (NNS sizes)))))))))
# (ROOT
#   (S
#     (NP (RB little))
#     (VP
#       (VBD did)
#       (SBAR
#         (S
#           (NP (PRP i))
#           (VP
#             (VBP know)
#             (SBAR
#               (IN that)
#               (S
#                 (NP (CD one) (NN moment))
#                 (VP
#                   (MD would)
#                   (VP
#                     (VB change)
#                     (NP (PRP$ my) (JJ whole) (NN life))))))))))))
# (ROOT
#   (S
#     (NP (DT these))
#     (VP
#       (VBP are)
#       (PP (IN for) (NP (PRP you)))
#       (NP (PRP$ my) (NN boy)))))
# (ROOT
#   (S
#     (VP
#       (VB wear)
#       (NP (PRP them))
#       (PP
#         (IN as)
#         (NP
#           (NP (DT a) (NN symbol))
#           (PP (IN of) (NP (NN honor) (CC and) (NN justice))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (MD will) (VP (VB make) (NP (PRP you) (JJ proud) (NN mama))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (ADVP (RB already))
#     (VP
#       (VBP have)
#       (NP (PRP$ my) (NN puss))
#       (PP (IN in) (NP (NNS boots))))))
# (ROOT
#   (FRAG
#     (SBAR
#       (WHADJP (WRB how) (JJ strange))
#       (S
#         (NP (PRP it))
#         (VP
#           (VBD was)
#           (S
#             (VP
#               (TO to)
#               (VP
#                 (VB give)
#                 (NP (DT a) (NN cat))
#                 (NP
#                   (NP (NNS boots))
#                   (SBAR (CC but) (FRAG (INTJ (UH whoa)))))))))))))
# (ROOT (S (NP (PRP i)) (VP (VBD looked) (ADJP (JJ good)))))
# (ROOT
#   (S
#     (CC and)
#     (SBAR
#       (IN as)
#       (S
#         (NP
#           (NP (DT the) (NN light))
#           (PP (IN of) (NP (PRP$ my) (NN path))))
# ...
# (ROOT
#   (S
#     (INTJ (UH no))
#     (INTJ (UH no))
#     (INTJ (UH no))
#     (NP (PRP it))
#     (VP (VBZ does) (RB not))))
# (ROOT (S (NP (PRP i)) (VP (VBD saved) (NP (PRP you)))))
# (ROOT (S (NP (PRP you)) (VP (VBD owed) (NP (PRP me)) (NP (CD one)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBD did)
#       (RB not)
#       (VP (VB tell) (NP (PRP me)) (PP (IN about) (NP (NN humpty)))))))
# (ROOT
#   (S
#     (ADVP (RB so) (RB now))
#     (NP (PRP you))
#     (VP (VBP owe) (NP (PRP me)) (NP (CD two)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (NP (NP (DT a) (NN lot)) (PP (IN of) (NP (NN work)))))))
# (ROOT (S (NP (PRP i)) (VP (VBP know))))
# (ROOT
#   (S
#     (CC but)
#     (NP (PRP i))
#     (VP (VBP am) (ADJP (JJ worth)) (NP (PRP it)))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (RB not)
#       (VP
#         (VBG getting)
#         (PRT (RB away))
#         (NP (NP (NN puss)) (PP (IN in) (NP (NNS boots))))))))
# (ROOT (NP (JJ wrong) (NNS boots)))
# (ROOT (NP (NN kitty)))
# (ROOT
#   (S (ADVP (RB now)) (NP (PRP we)) (VP (VBP are) (ADVP (RB even)))))
# (ROOT
#   (S
#     (NP (DT this))
#     (VP
#       (VBZ is)
#       (NP
#         (NP (PRP$ your))
#         (NP (FW san) (FW ricardo) (NN weather) (NN report))))))
# (ROOT
#   (FRAG
#     (PRN
#       (S
#         (NP
#           (NP (NNS chances))
#           (PP (IN of) (NP (DT a) (JJ giant) (NN goose))))
#         (VP (VBG destroying) (NP (DT the) (NN town)))))
#     (NP (QP (CD one) (CD hundred)) (NN percent))))
# (ROOT
#   (FRAG
#     (FRAG (ADVP (RB never)) (ADJP (JJ alone)))
#     (FRAG (ADVP (RB always)) (ADJP (RB together) (JJ humpty)))
#     (FRAG (CC and) (NP (NN puss) (NNS brothers)) (ADVP (RB forever)))))
# (ROOT (S (VP (VB come) (PP (IN on) (NP (NN sweetie))))))
# (ROOT
#   (S
#     (VP
#       (VB let)
#       (S
#         (NP (PRP us))
#         (VP
#           (VB get)
#           (ADVP (IN out) (PP (IN of) (ADVP (RB here))))
#           (SBAR
#             (IN before)
#             (S (NP (NN mama)) (VP (VBZ shows) (PRT (RP up))))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD should)
#       (VP
#         (VB make)
#         (NP (PRP you))
#         (PP (IN into) (NP (DT an) (NN egg) (NN salad) (NN sandwich)))))))
# (ROOT (S (NP (DT that)) (VP (VBZ is) (ADJP (JJ disgusting)))))
# (ROOT
#   (S
#     (VP (VB give) (NP (PRP me)) (NP (DT the) (NN goose) (NN humpty)))))
# (ROOT
#   (S
#     (NP (DT no))
#     (VP
#       (MD can)
#       (VP
#         (VB do)
#         (SBAR (S (NP (PRP i)) (VP (VBP am) (ADJP (JJ afraid)))))))))
# (ROOT
#   (S
#     (S
#       (VP
#         (VB see)
#         (NP (DT the) (NNS mamas))
#         (PP (IN on) (NP (PRP$ her) (NN way)))))
#     (CC and)
#     (S
#       (SBAR
#         (WHADVP (WRB when))
#         (S
#           (NP (PRP she))
#           (VP
#             (VBZ gets)
#             (S
#               (ADVP (RB here))
#               (NP (PRP it))
#               (VP
#                 (VBZ is)
#                 (NP
#                   (NP (FW byebye) (FW san) (FW ricardo))
#                   (CC and)
#                   (NP (NN everything))))))))
#       (NP (PRP you))
#       (ADVP (RB ever))
#       (VP (VBD cared) (ADVP (RB about))))))
# (ROOT
#   (S
#     (PRN
#       (S
#         (NP (NP (NN revenge)) (PP (IN on) (NP (PRP me))))
#         (VP (VBZ is) (NP (CD one) (NN thing)))))
#     (SBAR (CC but) (WHADVP (WRB why)) (FRAG (NP (NNP imelda))))))
# (ROOT (X (ADVP (WRB why)) (NP (DT the) (NN orphanage))))
# (ROOT (S (NP (DT this)) (VP (VBZ is) (NP (PRP$ our) (NN home)))))
# (ROOT (S (NP (PRP you)) (VP (VBP mean) (NP (PRP$ your) (NN home)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (ADVP (RB never))
#     (VP (VBD belonged) (ADVP (RB here)))))
# (ROOT
#   (S
#     (S
#       (NP (PRP we))
#       (VP
#         (VBD had)
#         (NP
#           (DT a)
#           (NN plan)
#           (S
#             (VP
#               (TO to)
#               (VP
#                 (VB get)
#                 (ADVP (IN out) (PP (IN of) (ADVP (RB here))))))))))
#     (CC but)
#     (S
#       (ADVP (RB then))
#       (NP (PRP you))
#       (VP (VBD became) (NP (DT a) (NN hero))))
#     (CC and)
#     (S
#       (NP (PRP you))
#       (VP
#         (VBD picked)
#         (NP (DT this) (NN place))
#         (PP (IN over) (NP (PRP me)))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP (VBD left) (NP (PRP me)) (PP (IN with) (NP (NN nothing))))))
# (ROOT (ADJP (JJ humpty)))
# (ROOT
#   (S
#     (PRN (S (NP (PRP i)) (VP (VBP am) (ADJP (JJ sorry)))))
#     (NP (PRP i))
#     (VP (VBP hurt) (NP (PRP you)))))
# (ROOT
#   (S
#     (CC but)
#     (VP
#       (VBP do)
#       (RB not)
#       (VP
#         (VB take)
#         (NP (PRP it))
#         (PRT (RP out))
#         (PP (IN on) (NP (DT these) (NNS people)))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (ADJP (ADJP (JJR better)) (PP (IN than) (NP (DT this)))))))
# (ROOT (S (INTJ (UH no)) (NP (PRP i)) (VP (VBP am) (RB not))))
# (ROOT (S (INTJ (UH oh)) (VP (VB come) (PRT (RP on)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP know) (NP (DT the) (JJ real) (NN humpty)))))
# (ROOT
#   (S
#     (NP (DT the) (NN way))
#     (NP (PRP you))
#     (VP (VBD saw) (NP (DT the) (NN world)))))
# (ROOT (NP (DT the) (NN inventor)))
# (ROOT (NP (DT the) (NN dreamer)))
# (ROOT
#   (SBARQ
#     (WHNP (WP what))
#     (SQ (VP (VBD happened) (PP (IN to) (NP (DT that) (NN guy)))))))
# (ROOT (S (NP (PRP i))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP think)
#       (SBAR
#         (S (NP (PRP it)) (VP (VBZ is) (ADJP (RB too) (JJ late))))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (VBZ is)
#       (ADVP (RB never))
#       (ADJP (RB too) (JJ late))
#       (S
#         (VP (TO to) (VP (VB do) (NP (DT the) (JJ right) (NN thing))))))))
# (ROOT
#   (S
#     (ADVP (RB together))
#     (NP (PRP we))
#     (VP (MD can) (VP (VB save) (NP (FW san) (FW ricardo))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD can)
#       (VP
#         (VB forgive)
#         (S
#           (NP (PRP you))
#           (ADJP (JJ humpty))
#           (SBAR
#             (IN if)
#             (S
#               (NP (PRP you))
#               (VP (VBP help) (NP (PRP me)) (ADVP (RB now))))))))))
# (ROOT (ADVP (RB really)))
# (ROOT
#   (S
#     (PP (IN after) (NP (NN everything)))
#     (NP (PRP i))
#     (VP (VBP put) (NP (PRP you)) (PP (IN through)))))
# (ROOT
#   (S
#     (PRN (S (VP (VB prove) (PP (IN to) (NP (PRP me))))))
#     (NP (EX there))
#     (VP
#       (VBZ is)
#       (ADVP (RB still))
#       (NP (NP (DT a) (JJ good) (NN egg)) (PP (IN in) (NP (PRP you)))))))
# (ROOT (S (NP (PRP i)) (VP (MD will) (VP (VB try)))))
# (ROOT (S (NP (NNS goggles)) (VP (VBP check))))
# (ROOT
#   (S
#     (VP
#       (VB get)
#       (NP (DT the) (NN baby))
#       (PP (IN over) (NP (DT the) (NN bridge))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (VP
#         (VB get)
#         (NP (DT the) (NN mother))
#         (S (VP (TO to) (VP (VB follow))))))))
# (ROOT
#   (FRAG
#     (ADJP
#       (JJ ok)
#       (SBAR (S (VP (VB give) (NP (PRP me)) (NP (DT a) (NN puss))))))))
# (ROOT (NP (NN mama) (NN goose)))
# (ROOT (S (VP (VB wait))))
# (ROOT
#   (S
#     (ADVP (RB just))
#     (VP
#       (VB follow)
#       (S
#         (NP (PRP me) (CC and) (PRP i))
#         (VP
#           (MD will)
#           (VP
#             (VB lead)
#             (NP (PRP you))
#             (PP (IN to) (NP (PRP$ your) (NN baby)))))))))
# (ROOT (INTJ (UH no)))
# (ROOT (NP (RB not) (DT that) (NN way)))
# (ROOT (NP (JJ pequeo) (NN help)))
# (ROOT (S (VP (VB hang) (PRT (RP on)))))
# (ROOT (S (NP (DT that)) (VP (VBZ is) (NP (PRP$ my) (NN boy)))))
# (ROOT
#   (S
#     (VP
#       (VB come)
#       (PP (IN with) (NP (PRP me)))
#       (NP (NN mama) (NN goose)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP know)
#       (SBAR
#         (WHADVP (WRB where))
#         (S (NP (PRP$ your) (NN baby)) (VP (VBZ is)))))))
# (ROOT (ADVP (RB here)))
# (ROOT (INTJ (NN look)))
# (ROOT
#   (S
#     (NP (JJ humpty))
#     (VP (VB pick) (PRT (RP up)) (NP (DT the) (NN pace)))))
# (ROOT
#   (S (NP (PRP i)) (VP (VBP am) (VP (VBG trying) (NP (NN puss))))))
# (ROOT (S (NP (PRP i)) (VP (VBP am) (VP (VBG trying)))))
# (ROOT
#   (NP
#     (NP (ADJP (JJ sorry)) (NN egghead))
#     (SBAR
#       (S
#         (NP (PRP we))
#         (VP
#           (VBP want)
#           (NP (QP (JJR more) (IN than) (RB just)) (NNS eggs)))))))
# (ROOT
#   (FRAG
#     (PRN
#       (SBAR
#         (RB so)
#         (WHADVP (WRB how) (IN about))
#         (S (NP (PRP you)) (VP (VBP give) (NP (PRP us))))))
#     (SBAR (IN that) (FRAG (NP (NN goose))))))
# (ROOT (ADJP (JJ humpty)))
# (ROOT (S (VP (VB get) (NP (PRP$ her)) (PRT (RP off)))))
# (ROOT (NP (JJ nice) (NNS moves)))
# (ROOT
#   (SBARQ
#     (WHNP (WP what))
#     (SQ
#       (MD would)
#       (NP (PRP you))
#       (VP (VB do) (PP (IN without) (NP (PRP me)))))))
# (ROOT (NP (NN freeze)))
# (ROOT (NP (NN comandante)))
# (ROOT (S (NP (PRP i)) (VP (MD can) (VP (VB explain)))))
# (ROOT
#   (S
#     (NP-TMP
#       (NP (FW gato))
#       (SBAR
#         (S
#           (NP (PRP you))
#           (VP
#             (VBP are)
#             (VP
#               (VBG going)
#               (ADVP (RB back))
#               (PP (IN to) (NP (NN jail)))
#               (SBAR
#                 (IN if)
#                 (S
#                   (NP (PRP it))
#                   (VP (VBZ is) (NP (DT the) (JJ last) (NN thing))))))))))
#     (NP (PRP i))
#     (VP (VBP do))))
# (ROOT (NP (JJ humpty) (NN hurry)))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP (VBP are) (ADVP (RB almost)) (ADVP (RB there)))))
# (ROOT
#   (S
#     (NP (PRP we))
#     (VP (VBP are) (ADVP (RB almost)) (ADVP (RB there)))))
# (ROOT (NP (NN puss) (NN help)))
# (ROOT (FRAG (NP (JJ humpty) (NN hang)) (PP (IN on))))
# (ROOT (NP (NN puss)))
# (ROOT
#   (S
#     (ADVP (RB here))
#     (NP (PRP we))
#     (VP (VBP are) (ADVP (RB again)) (NP (JJ right) (NN puss)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (RB not)
#       (VP
#         (VB leave)
#         (NP (PRP you))
#         (PP (IN behind) (NP (DT this) (NN time) (NN humpty)))))))
# (ROOT
#   (S (NP (PRP i)) (VP (VBP am) (ADJP (JJ sorry)) (NP (NN puss)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP have)
#       (VP
#         (VBN made)
#         (NP (DT a) (NN mess))
#         (PP (IN out) (PP (IN of) (NP (NN everything))))))))
# (ROOT
#   (S (NP (PRP i)) (VP (VBP am) (NP (DT a) (JJ rotten) (NN egg)))))
# (ROOT
#   (S (NP (PRP i)) (VP (VBP am) (RB not) (NP (DT a) (NN person)))))
# (ROOT (S (NP (PRP i)) (VP (VBP am) (RB not) (NP (DT a) (NN bird)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP am) (RB not) (NP (RB even) (DT a) (NN food)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP do)
#       (RB not)
#       (VP
#         (VB know)
#         (SBAR (WHNP (WP what)) (S (NP (PRP i)) (VP (VBP am))))))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (VBP are)
#       (SBAR
#         (WHNP (WP what))
#         (S
#           (NP (PRP you))
#           (VP (VBP have) (ADVP (RB always)) (VP (VBN been))))))))
# (ROOT (NP (PRP$ my) (NN brother)))
# (ROOT (S (NP (NNS brothers)) (ADVP (RB forever))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (MD can)
#       (RB not)
#       (VP (VB save) (NP (PRP us)) (NP (DT both))))))
# (ROOT (S (INTJ (UH yes)) (NP (PRP i)) (VP (MD can))))
# (ROOT (S (ADVP (RB just)) (VP (VB hang) (PRT (RP on)))))
# (ROOT
#   (S
#     (VP
#       (VB puss)
#       (S
#         (S
#           (NP (PRP you))
#           (VP
#             (VBP have)
#             (S (VP (TO to) (VP (VB save) (NP (DT the) (NN baby)))))))
#         (CC or)
#         (S
#           (NP (DT the) (NN mama))
#           (VP (MD will) (VP (VB destroy) (NP (FW san) (FW ricardo)))))))))
# (ROOT
#   (S
#     (NP (PRP it))
#     (VP
#       (VBZ is)
#       (NP
#         (DT the)
#         (JJ right)
#         (NN thing)
#         (S (VP (TO to) (VP (VB do))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (RB not)
#       (VP
#         (VB let)
#         (S (NP (PRP you)) (VP (VB go) (ADJP (JJ humpty))))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP know) (SBAR (S (NP (PRP you)) (VP (MD will) (RB not)))))))
# (ROOT
#   (S
#     (ADVP (RB so))
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (RB not)
#       (VP (VB make) (S (NP (PRP you)) (VP (VB choose)))))))
# (ROOT (ADJP (JJ humpty)))
# (ROOT (S (NP (PRP i)) (VP (VBP am) (ADJP (RB very) (JJ sorry)))))
# (ROOT (S (NP (PRP she)) (VP (VBZ is) (NP (JJ ok) (NN humpty)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (ADVP (RB always))
#     (VP
#       (VBD knew)
#       (SBAR
#         (IN that)
#         (S
#           (NP (PRP you))
#           (VP (VBD were) (ADJP (JJ good)) (ADVP (RB inside))))))))
# (ROOT (NP (NN goodbye) (NN humpty)))
# (ROOT
#   (S
#     (INTJ (UH yeah))
#     (NP (PRP i))
#     (VP
#       (VBP think)
#       (SBAR
#         (S
#           (S (NP (PRP it)) (VP (VBZ is) (ADJP (JJ wonderful))))
#           (CC and)
#           (S
#             (NP (PRP i))
#             (VP (VBD got) (NP (DT a) (NN goose) (NN egg)))))))))
# (ROOT (S (NP (PRP it)) (VP (VBZ is) (NP (PRP him)))))
# (ROOT (NP (NP (NN puss)) (PP (IN in) (NP (NNS boots)))))
# (ROOT
#   (S
#     (NP (PRP he))
#     (VP
#       (VBD saved)
#       (NP (PRP us))
#       (PP (IN from) (NP (DT the) (JJ giant) (NN goose))))))
# (ROOT
#   (S
#     (NP (PRP$ his) (NN sword))
#     (VP (VBZ is) (PP (IN like) (NP (NN lightning))))))
# (ROOT
#   (S
#     (NP (PRP they))
#     (VP
#       (VBP say)
#       (SBAR
#         (S (NP (PRP he)) (VP (VBZ has) (NP (CD ten) (NNS lives))))))))
# (ROOT
#   (S
#     (NP (PRP$ his) (NNS boots))
#     (VP
#       (VBP are)
#       (VP
#         (VBN made)
#         (PP
#           (IN of)
#           (NP (DT the) (JJS finest) (JJ corinthian) (NN leather)))))))
# (ROOT
#   (S
#     (NP (PRP he))
#     (ADVP (RB only))
#     (VP (VBZ drinks) (NP (JJ whole) (NN milk)))))
# (ROOT (NP (JJ good) (NN leche)))
# (ROOT
#   (S (NP (PRP he)) (VP (VBZ is) (S (NP (DT no)) (VP (VB outlaw))))))
# (ROOT (S (NP (PRP he)) (VP (VBD saved) (NP (PRP us)))))
# (ROOT (NP (NN meow)))
# (ROOT
#   (FRAG
#     (NP (NP (DT a) (NN gift)) (PP (IN for) (NP (PRP you))))
#     (NP (NN mama))))
# (ROOT (S (NP (PRP i)) (VP (VBP have) (S (VP (TO to) (VP (VB go)))))))
# (ROOT
#   (S
#     (NP (DT the) (NNS soldiers))
#     (VP (VBP are) (VP (VBG coming) (PP (IN for) (NP (PRP me)))))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (VBP am)
#       (ADJP (RB so) (JJ proud) (PP (IN of) (NP (PRP you))))
#       (NP (PRP$ my) (NN son)))))
# (ROOT
#   (S
#     (NP-TMP (NN today))
#     (NP (PRP you))
#     (VP
#       (VBD faced)
#       (NP (DT the) (NN past))
#       (PP (IN with) (NP (NN bravery) (CC and) (NN honor))))))
# (ROOT
#   (S (NP (PRP you)) (VP (VBD earned) (NP (DT those) (NNS boots)))))
# (ROOT
#   (S
#     (CC and)
#     (NP (DT the) (NNS people))
#     (VP
#       (VBP know)
#       (SBAR
#         (IN that)
#         (S
#           (NP (PRP you))
#           (VP
#             (VBP are)
#             (NP
#               (NP (FW san) (FW ricardos))
#               (NP (JJS greatest) (NN hero)))))))))
# (ROOT
#   (FRAG
#     (S
#       (NP (PRP i))
#       (VP (VBD did) (NP (PRP it)) (PP (IN for) (NP (PRP you)))))
#     (NP (NN mama))))
# (ROOT
#   (S
#     (NP (PRP you))
#     (VP
#       (MD will)
#       (ADVP (RB always))
#       (VP (VB be) (PP (IN in) (NP (PRP$ my) (NN heart)))))))
# (ROOT (FRAG (CC and) (NP (PRP you)) (PP (IN in) (NP (NN mine)))))
# (ROOT (NP (NN gato)))
# (ROOT (S (ADVP (RB there)) (NP (PRP he)) (VP (VBZ is))))
# (ROOT (S (NP (PRP i)) (VP (VBP see) (NP (PRP him)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP
#       (MD will)
#       (VP
#         (VB see)
#         (S
#           (NP (PRP you))
#           (ADVP (RB again))
#           (NP (NN kitty) (NNS softpaws)))))))
# (ROOT
#   (S (ADVP (RB sooner) (IN than)) (NP (PRP you)) (VP (VBP think))))
# (ROOT
#   (S (NP (PRP she)) (VP (VBZ is) (NP (DT a) (JJ bad) (NN kitty)))))
# (ROOT
#   (S
#     (NP (DT this))
#     (VP
#       (VBZ is)
#       (NP
#         (NP (DT the) (NN story))
#         (PP
#           (IN of)
#           (NP
#             (NP (DT a) (NN cat))
#             (SBAR
#               (WHNP (WP who))
#               (S (VP (VBD became) (NP (DT a) (NN hero)))))))))))
# (ROOT
#   (NP
#     (DT an)
#     (NML (S (VP (VB outlaw) (VP (VBN dedicated) (PP (IN to))))))
#     (NN justice)))
# (ROOT
#   (FRAG
#     (CC and)
#     (NP (DT a) (NN lover))
#     (PP (IN of) (NP (JJ beautiful) (NNS women)))))
# (ROOT (NP (DT a) (ADJP (JJ great) (JJ great)) (NN lover)))
# (ROOT (ADVP (RB really)))
# (ROOT (S (NP (PRP it)) (VP (VBZ is) (ADJP (JJ crazy)))))
# (ROOT
#   (S
#     (NP (PRP i))
#     (VP (VBP am) (NP (NP (NNS puss)) (PP (IN in) (NP (NNS boots)))))))
# (ROOT
#   (S
#     (CC and)
#     (NP (PRP$ my) (NN name))
#     (VP (MD would) (VP (VB become) (NP (NN legend))))))
# (ROOT (NP (NN meow)))
